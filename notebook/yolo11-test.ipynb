# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/bestdata/dataset_with_background/labels/val/folder_b5 (177).txt
# /kaggle/input/bestdata/dataset_with_background/labels/val/sau_cuon_la_150.txt
# /kaggle/input/bestdata/dataset_with_background/labels/val/brown_b2 (185).txt
# /kaggle/input/bestdata/dataset_with_background/labels/val/anh_chupbs (31).txt
# /kaggle/input/bestdata/dataset_with_background/labels/val/brown_spot_link4 (77).txt
# /kaggle/input/bestdata/dataset_with_background/labels/val/brown_b4 (35).txt
# /kaggle/input/bestdata/dataset_with_background/labels/val/brown_b2 (193).txt
# /kaggle/input/bestdata/dataset_with_background/labels/val/sbf_13.txt
# /kaggle/input/bestdata/dataset_with_background/labels/val/brown_spot_link4 (67).txt
# /kaggle/input/bestdata/dataset_with_background/labels/val/sau_cuon_la_158.txt
# /kaggle/input/bestdata/dataset_with_background/labels/val/blast_b3 (59).txt
# /kaggle/input/bestdata/dataset_with_background/labels/val/folder_b5 (475).txt
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 881.4/881.4 kB 21.1 MB/s eta 0:00:00
# ...

# %%
yaml_content = f"""
test: /kaggle/input/bestdata/dataset_with_background/images/test
train: /kaggle/input/bestdata/dataset_with_background/images/train
val: /kaggle/input/bestdata/dataset_with_background/images/val

# Classes
names:
  0: folder
  1: blast
  2: brown
"""

output_path = 'data1.yaml'
with open(output_path, 'w') as file:
    file.write(yaml_content)

print(f"YAML file has been saved to {output_path}")
# Out:
# YAML file has been saved to data1.yaml

# %%
# !pip uninstall wandb -y
# Out:
# Found existing installation: wandb 0.18.1
# Uninstalling wandb-0.18.1:
#   Successfully uninstalled wandb-0.18.1

# %%
# Start training from a pretrained *.pt model using GPUs 0 and 1
# !yolo detect train data=/kaggle/working/data1.yaml model=yolo11n.pt epochs=300 batch=64 device=0,1
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████████████████████████████████| 5.35M/5.35M [00:00<00:00, 99.3MB/s]
# Ultralytics 8.3.3 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
#                                                 CUDA:1 (Tesla T4, 15095MiB)
# ...

# %%
import os
import subprocess
from IPython.display import FileLink, display

def download_file(path, download_file_name):
    os.chdir('/kaggle/working/')
    zip_name = f"/kaggle/working/{download_file_name}.zip"
    command = f"zip {zip_name} {path} -r"
    result = subprocess.run(command, shell=True, capture_output=True, text=True)
    if result.returncode != 0:
        print("Unable to run zip command!")
        print(result.stderr)
        return
    display(FileLink(f'{download_file_name}.zip'))

# %%
download_file('/kaggle/working/runs/detect', 'yolo11_trainning')
# Out:
# /kaggle/working/yolo11_trainning.zip
